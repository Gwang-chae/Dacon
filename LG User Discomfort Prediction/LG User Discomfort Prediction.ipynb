# %%
# 베이지안 최적화 사용하려면 먼저 pip install 진행
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.19.4)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=a26e04488b07e3d84602b3b2927b7271d713d1da2526a6cff3a0550c3d253123
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %%
# from bayes_opt import BayesianOptimization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.model_selection import GridSearchCV, train_test_split, cross_validate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, PReLU
from tensorflow.keras.metrics import AUC
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tqdm import tqdm

import lightgbm as lgbm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import scipy.stats as stats
import seaborn as sns
import tensorflow as tf


# train data load
train_err = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/train_err_data.csv')
train_quality = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/train_quality_data.csv')
train_problem = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/train_problem_data.csv')

# test data load
test_err = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/test_err_data.csv')
test_quality = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/test_quality_data.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,11,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(f'train_err의 고유 user_id는 {len(train_err.user_id.unique())}개 입니다')
print(f'train_quality의 고유 user_id는 {len(train_quality.user_id.unique())}개 입니다')
print(f'train_problem의 고유 user_id는 {len(train_problem.user_id.unique())}개 입니다')
print()
print(f'test_err의 고유 user_id는 {len(test_err.user_id.unique())}개 입니다')
print(f'test_quality의 고유 user_id는 {len(test_quality.user_id.unique())}개 입니다')
# Out:
# train_err의 고유 user_id는 15000개 입니다
# train_quality의 고유 user_id는 8281개 입니다
# train_problem의 고유 user_id는 5000개 입니다
#
# test_err의 고유 user_id는 14998개 입니다
# test_quality의 고유 user_id는 8268개 입니다

# %% [markdown]
# # train_err 파일

# %%
# train_err의 정보 확인
# train_err는 user_id, timie, model_nm, fwver, errtype, errcode 컬럼이 존재
# model_nm, fwver, errcode는 각각 object 형태
print(train_err.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16554663 entries, 0 to 16554662
# Data columns (total 6 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   time      int64
#  2   model_nm  object
#  3   fwver     object
#  4   errtype   int64
#  5   errcode   object
# dtypes: int64(3), object(3)
# memory usage: 757.8+ MB
# None

# %%
# train_err의 결측치 확인
print(train_err.isnull().sum())

# 확인결과 결측치는 errcode 컬럼에서 단 한개
# 해당 행과 앞뒤 행까지 확인
null_index = train_err.index[train_err['errcode'].isna()][0]
display(train_err.iloc[null_index-1:null_index+2, :])
# Out:
# user_id     0
# time        0
# model_nm    0
# fwver       0
# errtype     0
# errcode     1
# dtype: int64
#          user_id            time model_nm       fwver  errtype errcode
# 3825743    13639  20201121174110  model_2  04.33.1261       31       0
# 3825744    13639  20201121191718  model_2  04.33.1261        5     NaN
# 3825745    13639  20201121191718  model_2  04.33.1261        5   40013

# %%
# 16554663개 중에 1개 행렬이므로 해당 행 제거
# train_err = train_err.dropna()

# 혹은 바로 다음 행과 컬럼 배열이 동일하므로 40013으로 대체
train_err = train_err.fillna(40013)

# %%
# train_err의 각 컬럼간의 교차 분석
# user_id, time은 우선적으로 제외하고
# model_nm, fwver, errtype, errcode로 분석 진행
# 비식별 데이터지만 컬럼 이름으로 유추컨대
# model_nm - 모델 이름, fwver - 펌웨어 버전, errtype - 에러타입, errcode - 에러 코드라 추정해 볼 수 있음
                              # 펌웨어란 하드웨어의 제어(low-level control)와 구동을 담당하는 일종의 운영체제
# 추정이 맞다면 위 컬럼들은 범주형 변수에 해당

columns = ['model_nm','fwver','errtype','errcode']

for column in columns:
    print(f'{column}의 최빈값은 {train_err[column].mode()[0]}입니다.')
# Out:
# model_nm의 최빈값은 model_1입니다.
# fwver의 최빈값은 04.16.3553입니다.
# errtype의 최빈값은 23입니다.
# errcode의 최빈값은 1입니다.

# %%
# 시각화
fig = plt.figure(figsize=(12, 6))
ax1 = plt.subplot(121)
ax1.plot(train_err.groupby(train_err['model_nm'])['errtype'].count())
ax1.title.set_text('errtype count By model_nm')
ax1.set_xlabel('model_nm')
ax1.set_ylabel('errtype')

ax2 = plt.subplot(122)
ax2.plot(train_err.groupby(train_err['fwver'])['errtype'].count(), color='orange')
ax2.title.set_text('errtype count By fwver')
ax2.set_xlabel('fwver')
ax2.set_ylabel('errtype')
plt.xticks(rotation=90)
fig.tight_layout()

plt.show()

# model_nm, fwver 각각의 최빈값인 model_1, 04.16.3553에서
# 가장 많은 수의 errtype count가 나왔고
# model_nm의 경우, model_1, model_0, model_2 순으로 errtype count가 높으며
# model_1일 때를 제외하고 model 넘버가 높아질수록 errtype count가 감소
# fwver의 경우, 04.16.3553, 03.11.1167 등을 비롯한 특정 fwver 5개에서
# 유독 높은 errtype count를 확인할 수 있음

# %%
#카이제곱검정을 통한 독립성 검정

# 교차표 생성 및 카이제곱검정
for first_column in columns:
    for second_column in columns:
        # 비교군이 같은 경우 continue
        if first_column == second_column:
            continue
        else:
            result = pd.crosstab(train_err[first_column], train_err[second_column])
            print(f'{first_column}과 {second_column}의 p-value는 {stats.chi2_contingency(observed=result)[1]}입니다')
# Out:
# model_nm과 fwver의 p-value는 0.0입니다
# model_nm과 errtype의 p-value는 0.0입니다
# model_nm과 errcode의 p-value는 0.0입니다
# fwver과 model_nm의 p-value는 0.0입니다
# fwver과 errtype의 p-value는 0.0입니다
# fwver과 errcode의 p-value는 0.0입니다
# errtype과 model_nm의 p-value는 0.0입니다
# errtype과 fwver의 p-value는 0.0입니다
# errtype과 errcode의 p-value는 0.0입니다
# errcode과 model_nm의 p-value는 0.0입니다
# errcode과 fwver의 p-value는 0.0입니다
# errcode과 errtype의 p-value는 0.0입니다

# %%
# 독립성 검정 결과로 나온
# 모든 두 컬럼들 사이의 p-value는 0.0으로 유의수준 0.05하에서 귀무가설 기각
# 따라서, 모든 두 컬럼들 사이에는 관련성이 존재

# %% [markdown]
# # train_quality 파일

# %%
# train_quality의 정보 확인
# train_err는 timie, user_id, fwver, quality_0 ~ quality_12 컬럼이 존재
# fwver, quality_5,7,8,9,10은 각각 object 형태
train_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828624 entries, 0 to 828623
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        828624 non-null  int64
#  1   user_id     828624 non-null  int64
#  2   fwver       788544 non-null  object
#  3   quality_0   684192 non-null  float64
#  4   quality_1   828624 non-null  int64
#  5   quality_2   788511 non-null  float64
#  6   quality_3   828624 non-null  int64
#  7   quality_4   828624 non-null  int64
#  8   quality_5   828604 non-null  object
#  9   quality_6   828624 non-null  int64
#  10  quality_7   828624 non-null  object
#  11  quality_8   828624 non-null  object
#  12  quality_9   828624 non-null  object
#  13  quality_10  828624 non-null  object
#  14  quality_11  828624 non-null  int64
#  15  quality_12  828624 non-null  int64
# dtypes: float64(2), int64(8), object(6)
# memory usage: 101.2+ MB

# %%
print(f'train_err의 고유 user_id는 {len(train_err.user_id.unique())}개 입니다')
print(f'train_quality의 고유 user_id는 {len(train_quality.user_id.unique())}개 입니다')
print(f'train_problem의 고유 user_id는 {len(train_problem.user_id.unique())}개 입니다')
# Out:
# train_err의 고유 user_id는 15000개 입니다
# train_quality의 고유 user_id는 8281개 입니다
# train_problem의 고유 user_id는 5000개 입니다

# %%
# train_problem에 한번이라도 나와 있는 유저는
# 시스템 풀질에 불편을 느꼈다고 할때

quality_user = train_quality.user_id.unique()
problem_user = train_problem.user_id.unique()
quality_problem_user = [x for x in quality_user if x in problem_user]
print(f'quality_user {len(quality_user)}명 중 불편을 느낀 user의 수는 {len(quality_problem_user)}명 입니다.')

# 따라서, quality_user 8281명 중 3167명은 불편을 느낌.
# Out:
# quality_user 8281명 중 불편을 느낀 user의 수는 3167명 입니다.

# %%
# object형태인 quality_5,7,8,9,10은
# 확인결과 숫자가 천단위로 넘어가면 ',' 가 붙기 때문에 object.
# 특이한 점은 quality_8의 경우, 
# 같은 수라도 어떤 값은 int, 어떤 값은 str로 표현. ex) 0, '0'
# 또한, quality_3, quality_4는 모두 0으로 버려도 무방

# string형태를 int로 바꿀 함수 정의
def string2num(x):
    # (,)( )과 같은 불필요한 데이터 정제
    x = re.sub(r"[^0-9]+", '', str(x))
    if x =='':
        pass
    else:
        return int(x)

# %%
# ','등 불필요한 문자열이 들어가 있어 object로 읽히던 컬럼들을 string2num 함수를 통해 int 형태로 변환

for i in tqdm(range(13)):
    quality = 'quality_' + str(i)
    train_quality[quality] = train_quality[quality].apply(string2num)
# Out:
# 100%|██████████| 13/13 [00:15<00:00,  1.15s/it]

# %%
# object 형태인 fwver은 최빈값으로 대체
# int 또는 float 형태인 quality_0, quality_1, quality_2는 평균값으로 결측값 대체

train_quality['fwver'] = train_quality['fwver'].fillna(train_quality['fwver'].mode()[0])
train_quality['quality_0'] = train_quality['quality_0'].fillna(train_quality['quality_0'].mean())
train_quality['quality_1'] = train_quality['quality_1'].fillna(train_quality['quality_1'].mean())
train_quality['quality_2'] = train_quality['quality_2'].fillna(train_quality['quality_2'].mean())
train_quality['quality_5'] = train_quality['quality_5'].fillna(train_quality['quality_5'].mean())
# Out:
# time          0
# user_id       0
# fwver         0
# quality_0     0
# quality_1     0
# quality_2     0
# quality_3     0
# quality_4     0
# quality_5     0
# quality_6     0
# quality_7     0
# quality_8     0
# quality_9     0
# quality_10    0
# quality_11    0
# quality_12    0
# dtype: int64

# %%
# 결측치를 ffill 방법으로 대체할 경우
train_quality = train_quality.fillna('ffill')

# ffill로 변경하면 연달아 na값을 경우 'ffill'로 채워지면서 object가 됨
# 따라서, 'ffill'로 채워진 부분을 수정해주고 넘어가야 함. -> 최빈값으로 대체
train_quality.loc[train_quality['quality_0'] == 'ffill','quality_0'] = train_quality['quality_0'].mode()[0]
train_quality.loc[train_quality['quality_2'] == 'ffill','quality_2'] = train_quality['quality_2'].mode()[0]
train_quality.loc[train_quality['quality_5'] == 'ffill','quality_5'] = train_quality['quality_5'].mode()[0]

# 기존 형태였던 float64로 변경
train_quality['quality_0'] = train_quality['quality_0'].astype(np.float64)
train_quality['quality_2'] = train_quality['quality_2'].astype(np.float64)
train_quality['quality_5'] = train_quality['quality_5'].astype(np.float64)
train_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 828624 entries, 0 to 828623
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        828624 non-null  int64
#  1   user_id     828624 non-null  int64
#  2   fwver       828624 non-null  object
#  3   quality_0   828624 non-null  float64
#  4   quality_1   828624 non-null  int64
#  5   quality_2   828624 non-null  float64
#  6   quality_5   828624 non-null  float64
#  7   quality_6   828624 non-null  int64
#  8   quality_7   828624 non-null  int64
#  9   quality_8   828624 non-null  int64
#  10  quality_9   828624 non-null  int64
#  11  quality_10  828624 non-null  int64
#  12  quality_11  828624 non-null  int64
#  13  quality_12  828624 non-null  int64
# dtypes: float64(3), int64(10), object(1)
# memory usage: 88.5+ MB

# %%
# quality_3, quality_4는 영행렬이므로 drop
train_quality = train_quality.drop(['quality_3','quality_4'], axis=1)
# 각 컬럼간의 상관관계
corr = train_quality.corr().astype('float64')
display(corr)
# Out:
#                 time   user_id  quality_0  ...  quality_10  quality_11  quality_12
# time        1.000000 -0.001218  -0.003096  ...    0.004219    0.002685    0.026708
# user_id    -0.001218  1.000000   0.006082  ...   -0.004560    0.010079    0.019467
# quality_0  -0.003096  0.006082   1.000000  ...    0.032233   -0.001862    0.004553
# quality_1   0.002777  0.007723  -0.001939  ...   -0.000853    0.550380    0.010572
# quality_2  -0.002073  0.003424   0.761576  ...    0.029363   -0.000900    0.005050
# quality_5   0.002549 -0.002753   0.066848  ...    0.604204   -0.006520    0.037741
# quality_6  -0.012724 -0.017417  -0.000211  ...    0.012151   -0.020196   -0.006204
# quality_7  -0.015707 -0.021609   0.000705  ...    0.015014   -0.027924   -0.007758
# quality_8   0.003519  0.004222  -0.000256  ...    0.000378    0.002014    0.010314
# quality_9  -0.004334  0.007148   0.450535  ...    0.061430    0.002465    0.010548
# quality_10  0.004219 -0.004560   0.032233  ...    1.000000    0.002096    0.062462
# quality_11  0.002685  0.010079  -0.001862  ...    0.002096    1.000000    0.071061
# quality_12  0.026708  0.019467   0.004553  ...    0.062462    0.071061    1.000000
#
# [13 rows x 13 columns]

# %%
# 상관관계 시각화
cmap = sns.color_palette("Blues")
f, ax = plt.subplots(figsize=(10, 7))
sns.heatmap(corr, cmap=cmap)

# %%
# quality가 어떤 변수인지는 모르겠으나
# 일단 fwv가 범주형 변수이므로 카이제곱검정을 시행해 보았음.
# 이 결과, 0으로만 이뤄진 quality_3, quality_4를 제외하고
# quality_5는 fwv와 독립.

for i in range(13):
    if i == 3 or i == 4:
        continue
    quality = 'quality_' + str(i)
    result = pd.crosstab(train_quality.fwver, train_quality[quality])
    p_value = stats.chi2_contingency(observed=result)[1]
    print(f'fwver와 quality_{i} 사이의 p_value값은 {p_value}입니다.')
# Out:
# fwver와 quality_0 사이의 p_value값은 0.0입니다.
# fwver와 quality_1 사이의 p_value값은 0.0입니다.
# fwver와 quality_2 사이의 p_value값은 0.0입니다.
# fwver와 quality_5 사이의 p_value값은 1.0입니다.
# fwver와 quality_6 사이의 p_value값은 0.0입니다.
# fwver와 quality_7 사이의 p_value값은 0.0입니다.
# fwver와 quality_8 사이의 p_value값은 0.0입니다.
# fwver와 quality_9 사이의 p_value값은 0.0입니다.
# fwver와 quality_10 사이의 p_value값은 0.0입니다.
# fwver와 quality_11 사이의 p_value값은 0.0입니다.
# fwver와 quality_12 사이의 p_value값은 0.0입니다.

# %%
# 향후, quality에서 전처리가 된다면
# fwv와의 카이제곱검정은 재진행이 필요
# 또한 quality간의 corr()를 통해
# 상관관계 분석도 해볼 수 있을 듯

# %% [markdown]
# # Preprocessing

# %%
# 데이콘 베이스라인 Modeling
# errtype counts를 변수로 problem에서 
# 한 번이라도 user_id가 나오면 오류가 발생했다고 설정

train_user_id_max = 24999
train_user_id_min = 10000
train_user_number = 15000

id_error = train_err[['user_id','errtype']].values
error = np.zeros((train_user_number,42))

for person_idx, err in tqdm(id_error):
    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    error[person_idx - train_user_id_min,err - 1] += 1
error.shape

# error와 동일한 방법으로 person_idx - 10000 위치에 
# person_idx의 problem이 한 번이라도 발생했다면 1
# 없다면 0
problem = np.zeros(15000)
problem[train_problem.user_id.unique()-10000] = 1 
problem.shape

# X = error
Y = problem
# Out:
# 100%|██████████| 16554663/16554663 [00:49<00:00, 337587.52it/s]

# %%
# train_quality 데이터 또한 위와 동일한 방법으로 처리
# 단, quality값의 총합을 변수로 생성

id_quality = train_quality[['user_id','quality_0','quality_1','quality_2','quality_5','quality_6','quality_7','quality_8','quality_9','quality_10','quality_11','quality_12']].values
quality = np.zeros((train_user_number,11))

# ffill등의 방식으로 결측치를 처리하면 float64형태인 컬럼으로 인해 
# id_quality 또한 float64형태로 바뀌면서 인덱싱에 문제가 생김
# 따라서, person_idx에 int()를 씌워주면서 값 대입
for person_idx, q0, q1, q2, q5, q6, q7, q8, q9, q10, q11,q12 in tqdm(id_quality):

    # person_idx - train_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    if q0 != 0 :
        quality[int(person_idx) - train_user_id_min, 0] += q0
    if q1 != 0 :
        quality[int(person_idx) - train_user_id_min, 1] += q1
    if q2 != 0 :
        quality[int(person_idx) - train_user_id_min, 2] += q2
    if q5 != 0 :
        quality[int(person_idx) - train_user_id_min, 3] += q5
    if q6 != 0 :
        quality[int(person_idx) - train_user_id_min, 4] += q6
    if q7 != 0 :
        quality[int(person_idx) - train_user_id_min, 5] += q7
    if q8 != 0 :
        quality[int(person_idx) - train_user_id_min, 6] += q8
    if q9 != 0 :
        quality[int(person_idx) - train_user_id_min, 7] += q9
    if q10 != 0 :
        quality[int(person_idx) - train_user_id_min, 8] += q10
    if q11 != 0 :
        quality[int(person_idx) - train_user_id_min, 9] += q11
    if q12 != 0 :
        quality[int(person_idx) - train_user_id_min, 10] += q12
# Out:
#   0%|          | 0/828624 [00:00<?, ?it/s]
#   1%|▏         | 11970/828624 [00:00<00:06, 119671.01it/s]
#   3%|▎         | 23379/828624 [00:00<00:06, 117940.07it/s]
#   4%|▍         | 37162/828624 [00:00<00:06, 123276.73it/s]
#   6%|▌         | 50205/828624 [00:00<00:06, 125338.90it/s]
#   8%|▊         | 63497/828624 [00:00<00:06, 127518.60it/s]
#   9%|▉         | 76712/828624 [00:00<00:05, 128872.08it/s]
#  11%|█         | 90318/828624 [00:00<00:05, 130946.47it/s]
#  13%|█▎        | 103808/828624 [00:00<00:05, 132105.52it/s]
#  14%|█▍        | 117626/828624 [00:00<00:05, 133868.76it/s]
#  16%|█▌        | 131113/828624 [00:01<00:05, 134166.94it/s]
#  17%|█▋        | 144283/828624 [00:01<00:05, 133416.76it/s]
#  19%|█▉        | 157401/828624 [00:01<00:05, 132447.92it/s]
#  21%|██        | 171012/828624 [00:01<00:04, 133525.07it/s]
#  22%|██▏       | 184259/828624 [00:01<00:04, 133152.91it/s]
#  24%|██▍       | 197960/828624 [00:01<00:04, 134284.82it/s]
#  26%|██▌       | 211339/828624 [00:01<00:04, 132808.70it/s]
#  27%|██▋       | 224817/828624 [00:01<00:04, 133393.19it/s]
#  29%|██▊       | 238136/828624 [00:01<00:04, 130798.49it/s]
#  30%|███       | 251585/828624 [00:01<00:04, 131882.86it/s]
#  32%|███▏      | 264773/828624 [00:02<00:04, 130868.10it/s]
#  34%|███▎      | 277862/828624 [00:02<00:04, 128654.32it/s]
#  35%|███▌      | 290977/828624 [00:02<00:04, 129390.84it/s]
#  37%|███▋      | 304096/828624 [00:02<00:04, 129925.05it/s]
#  38%|███▊      | 317457/828624 [00:02<00:03, 131007.12it/s]
#  40%|███▉      | 330976/828624 [00:02<00:03, 132232.56it/s]
#  42%|████▏     | 344207/828624 [00:02<00:03, 130932.15it/s]
#  43%|████▎     | 357614/828624 [00:02<00:03, 131854.11it/s]
#  45%|████▍     | 370807/828624 [00:02<00:03, 129211.41it/s]
#  46%|████▋     | 384238/828624 [00:02<00:03, 130697.36it/s]
#  48%|████▊     | 397360/828624 [00:03<00:03, 130847.59it/s]
#  50%|████▉     | 410514/828624 [00:03<00:03, 131054.40it/s]
#  51%|█████     | 423719/828624 [00:03<00:03, 131350.23it/s]
#  53%|█████▎    | 437060/828624 [00:03<00:02, 131958.41it/s]
#  54%|█████▍    | 450621/828624 [00:03<00:02, 133031.33it/s]
#  56%|█████▌    | 463930/828624 [00:03<00:02, 132233.55it/s]
#  58%|█████▊    | 477159/828624 [00:03<00:02, 131272.72it/s]
#  59%|█████▉    | 490454/828624 [00:03<00:02, 131770.27it/s]
#  61%|██████    | 504098/828624 [00:03<00:02, 133136.57it/s]
#  63%|██████▎   | 517961/828624 [00:03<00:02, 134736.50it/s]
#  64%|██████▍   | 531444/828624 [00:04<00:02, 133730.41it/s]
#  66%|██████▌   | 544826/828624 [00:04<00:02, 129290.52it/s]
#  67%|██████▋   | 557793/828624 [00:04<00:02, 126921.49it/s]
#  69%|██████▉   | 570917/828624 [00:04<00:02, 128186.58it/s]
#  70%|███████   | 583764/828624 [00:04<00:01, 126462.90it/s]
#  72%|███████▏  | 597132/828624 [00:04<00:01, 128542.77it/s]
#  74%|███████▎  | 610013/828624 [00:04<00:01, 126298.91it/s]
#  75%|███████▌  | 622915/828624 [00:04<00:01, 127100.91it/s]
#  77%|███████▋  | 635826/828624 [00:04<00:01, 127694.82it/s]
#  78%|███████▊  | 648611/828624 [00:04<00:01, 125125.72it/s]
#  80%|███████▉  | 661146/828624 [00:05<00:01, 123947.16it/s]
#  81%|████████▏ | 673559/828624 [00:05<00:01, 120305.27it/s]
#  83%|████████▎ | 685854/828624 [00:05<00:01, 121085.50it/s]
#  84%|████████▍ | 698962/828624 [00:05<00:01, 123918.77it/s]
#  86%|████████▌ | 711389/828624 [00:05<00:00, 123835.32it/s]
#  87%|████████▋ | 724962/828624 [00:05<00:00, 127178.18it/s]
#  89%|████████▉ | 738166/828624 [00:05<00:00, 128597.58it/s]
#  91%|█████████ | 751058/828624 [00:05<00:00, 125588.35it/s]
#  92%|█████████▏| 763885/828624 [00:05<00:00, 126378.01it/s]
#  94%|█████████▍| 776899/828624 [00:05<00:00, 127481.46it/s]
#  95%|█████████▌| 790129/828624 [00:06<00:00, 128886.56it/s]
#  97%|█████████▋| 803037/828624 [00:06<00:00, 127216.80it/s]
# 100%|██████████| 828624/828624 [00:06<00:00, 129649.23it/s]

# %%
# 위에서 만든 error와 quality를 concatenate
X = np.concatenate((error, quality), axis = 1)
Y = problem

# %%
# train_err의 fwver, model_nm을 변수로 사용할 경우
# 각 user_id에서 최빈값의 fwver, model_nm을 추출

# fwv = []
# for i in tqdm(range(train_user_id_min, train_user_id_max+1)):
#     fwv.append(train_err[train_err['user_id'] == i].fwver.mode()[0])

# fwv = np.array(fwv)

# model = []
# for i in tqdm(range(train_user_id_min, train_user_id_max+1)):
#     model.append(train_err[train_err['user_id'] == i].model_nm.mode()[0])

# model = np.array(model)

# 위에서 만든 error array와
# fwv, model을 concat하기 위해 각각 DF, Series로 변경
# error_df = pd.DataFrame(X)

# fwv_series = pd.Series(fwv,name='fwv')
# model_series = pd.Series(model,name='model')

# fwv, model concat
# error_df = pd.concat([error_df,fwv_series], axis=1)
# error_df = pd.concat([error_df,model_series], axis=1)
# error_df.head()

##(시도) errtype count가 1000개도 안되는 컬럼들을 drop
# error_df = error_df.drop([7,8,18,20,29], axis=1)
# error_df

# fwv, model 컬럼 안의 값들의
# 관계성을 주지 않기 위해 가변수화
# X = pd.get_dummies(error_df)

# %%
# 이상치 처리(이건 나중에 고칠 필요가 있음)
# zscore 바깥의 값들을 이상치로 보고 평균값으로 대체

zscore = 1.8
for col in error_df.columns:
    outliers = error_df[col][np.abs(stats.zscore(error_df[col])) > zscore]
    col_mean = np.mean(error_df.loc[~error_df[col].isin(outliers), col])
    error_df.loc[error_df[col].isin(outliers), col] = col_mean
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:2419: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
# Normalization

# scaler = MinMaxScaler()
# scaler.fit(X)
# X = scaler.transform(X)

# from sklearn.preprocessing import RobustScaler
# scaler = RobustScaler()
# scaler.fit(X)
# X = scaler.transform(X)

# %%
# train_test_split
# K-Fold를 할 경우 하지 않고 skip
x_train, x_val, y_train, y_val = \
train_test_split(X, Y, test_size=0.1, random_state=42, stratify=Y)
x_train.shape
# Out:
# (13500, 53)

# %%
# TestSet

test_user_id_max = 44998
test_user_id_min = 30000
test_user_number = 14999

test_err = test_err.dropna()

id_error = test_err[['user_id','errtype']].values
test_x = np.zeros((test_user_number,42))
for person_idx, err in tqdm(id_error):
    # person_idx - test_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    test_x[person_idx - test_user_id_min,err - 1] += 1
# test_x = test_x.reshape(test_x.shape[0],-1)
print(test_x.shape)
# Out:
# 100%|██████████| 16532644/16532644 [00:45<00:00, 366135.49it/s]
# (14999, 42)

# %%
# ,가 들어가 있어 object로 읽히던 컬럼들을 string2num 함수를 통해
# int 형태로 변환

# ','등 불필요한 문자열이 들어가 있어 object로 읽히던 컬럼들을 string2num 함수를 통해 int 형태로 변환

for i in tqdm(range(13)):
    quality = 'quality_' + str(i)
    test_quality[quality] = test_quality[quality].apply(string2num)

# %%
test_quality.isnull().sum()
# Out:
# time               0
# user_id            0
# fwver          22764
# quality_0     106584
# quality_1         11
# quality_2      21115
# quality_3          0
# quality_4          0
# quality_5         44
# quality_6          0
# quality_7          0
# quality_8          0
# quality_9          0
# quality_10         0
# quality_11         0
# quality_12         0
# dtype: int64

# %%
# # object 형태인 fwver은 최빈값으로
# # int 또는 float 형태인 quality_0, quality_1, quality_2, ... 는 평균값으로 결측값 대체

test_quality['fwver'] = test_quality['fwver'].fillna(test_quality['fwver'].mode()[0])
test_quality['quality_0'] = test_quality['quality_0'].fillna(test_quality['quality_0'].mean())
test_quality['quality_1'] = test_quality['quality_1'].fillna(test_quality['quality_1'].mean())
test_quality['quality_2'] = test_quality['quality_2'].fillna(test_quality['quality_2'].mean())
test_quality['quality_5'] = test_quality['quality_5'].fillna(test_quality['quality_5'].mean())
test_quality['quality_6'] = test_quality['quality_6'].fillna(test_quality['quality_6'].mean())

# %%
# trainset에서 행한 방식과 동일하게 train_quality 처리

id_quality = test_quality[['user_id','quality_0','quality_1','quality_2','quality_5','quality_6','quality_7','quality_8','quality_9','quality_10','quality_11','quality_12']].values
quality = np.zeros((test_user_number,11))

for person_idx, q0, q1, q2, q5, q6, q7, q8, q9, q10, q11,q12 in tqdm(id_quality):
    # person_idx - test_user_id_min 위치에 person_idx, errtype에 해당하는 error값을 +1
    if q0 != 0 :
        quality[int(person_idx) - test_user_id_min, 0] += q0
    if q1 != 0 :
        quality[int(person_idx) - test_user_id_min, 1] += q1
    if q2 != 0 :
        quality[int(person_idx) - test_user_id_min, 2] += q2
    if q5 != 0 :
        quality[int(person_idx) - test_user_id_min, 3] += q5
    if q6 != 0 :
        quality[int(person_idx) - test_user_id_min, 4] += q6
    if q7 != 0 :
        quality[int(person_idx) - test_user_id_min, 5] += q7
    if q8 != 0 :
        quality[int(person_idx) - test_user_id_min, 6] += q8
    if q9 != 0 :
        quality[int(person_idx) - test_user_id_min, 7] += q9
    if q10 != 0 :
        quality[int(person_idx) - test_user_id_min, 8] += q10
    if q11 != 0 :
        quality[int(person_idx) - test_user_id_min, 9] += q11
    if q12 != 0 :
        quality[int(person_idx) - test_user_id_min, 10] += q12
# Out:
# 100%|██████████| 747972/747972 [00:05<00:00, 132614.60it/s]

# %%
# 위에서 만든 test_x와 quality를 concatenate
X_test = np.concatenate((test_x, quality), axis = 1)
X_test.shape
# Out:
# (14999, 53)

# %%
# TestSet 이상치 처리 및 가변수화, 정규화

test_df = pd.DataFrame(X_test)

zscore = 1.8
for col in test_df.columns:
    outliers = test_df[col][np.abs(stats.zscore(test_df[col])) > zscore]
    col_mean = np.mean(test_df.loc[~test_df[col].isin(outliers), col])
    test_df.loc[test_df[col].isin(outliers), col] = col_mean

X_test = pd.get_dummies(test_df)

scaler.fit(X_test)
X_test = scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:2419: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
# test_err의 fwv, model_nm을 사용할 경우, 참고용

# # fwv_test = []
# # for i in tqdm(range(test_user_id_min, test_user_id_max+1)):
# #     if i == 43262:
# #         fwv_test.append(test_err.fwver.mode()[0])
# #     fwv_test.append(test_err[test_err['user_id'] == i].fwver.mode()[0])

# # fwv_test = np.array(fwv_test)

# # model_test = []
# # for i in tqdm(range(test_user_id_min, test_user_id_max+1)):
# #     if i == 43262:
# #         model_test.append(test_err.model_nm.mode()[0])
# #     model_test.append(test_err[test_err['user_id'] == i].model_nm.mode()[0])

# # model_test = np.array(model_test)
    
# # fwv_series_test = pd.Series(fwv_test,name='fwv')
# # model_series_test = pd.Series(model_test,name='model')

# test_x = pd.DataFrame(test_x)

# zscore = 1.8
# for col in test_x.columns:
#     outliers = test_x[col][np.abs(stats.zscore(test_x[col])) > zscore]
#     col_mean = np.mean(test_x.loc[~test_x[col].isin(outliers), col])
#     test_x.loc[test_x[col].isin(outliers), col] = col_mean

# # test_x = pd.concat([test_x,fwv_series_test], axis=1)
# # test_x = pd.concat([test_x,model_series_test], axis=1)
# # test_x = test_x.drop([7,8,18,20,29], axis=1)

# # X_test = pd.get_dummies(test_x)
# # Normalization
# scaler = MinMaxScaler()
# scaler.fit(test_x)
# X_test = scaler.transform(test_x)

# X_test.shape

# %% [markdown]
# # Modeling

# %% [markdown]
# ## NN

# %%
## NN

# def build_nn():
earlystop = EarlyStopping(patience=10)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss',
                                        patience=2,
                                        factor=0.8,
                                        min_lr=1e-7,
                                        verbose=1)
model_check = ModelCheckpoint( #에포크마다 현재 가중치를 저장    
        filepath="./lg_nn.h5", #모델 파일 경로
        monitor='val_loss',  # val_loss 가 좋아지지 않으면 모델 파일을 덮어쓰지 않음.
        save_best_only=True)

callbacks = [earlystop, learning_rate_reduction, model_check]

model = Sequential()
model.add(Dense(7500, kernel_initializer='he_normal',
                input_shape=(x_train.shape[1],)))  # input_shape로 input layer의 역할까지도 처리
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.7))

model.add(Dense(3750, kernel_initializer='he_normal'))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.7))

model.add(Dense(1, activation='sigmoid', kernel_initializer='he_normal'))

model.compile(optimizer=Adam(learning_rate=0.0001),
            loss='binary_crossentropy',
            metrics=['binary_accuracy',AUC()])

history = model.fit(x_train,
                    y_train,
                    epochs=100,
                    verbose=1,
                    validation_data=(x_val,y_val),
                    callbacks=callbacks)
    
    # return history
# Out:
# Epoch 1/100
# 422/422 [==============================] - 5s 9ms/step - loss: 0.9964 - binary_accuracy: 0.6459 - auc_1: 0.6738 - val_loss: 0.6428 - val_binary_accuracy: 0.7527 - val_auc_1: 0.7493
# Epoch 2/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.8589 - binary_accuracy: 0.6918 - auc_1: 0.6961 - val_loss: 0.6288 - val_binary_accuracy: 0.7520 - val_auc_1: 0.7571
# Epoch 3/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.7918 - binary_accuracy: 0.6956 - auc_1: 0.7014 - val_loss: 0.6147 - val_binary_accuracy: 0.7500 - val_auc_1: 0.7560
# Epoch 4/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.7418 - binary_accuracy: 0.7022 - auc_1: 0.7080 - val_loss: 0.5700 - val_binary_accuracy: 0.7627 - val_auc_1: 0.7679
# Epoch 5/100
# 422/422 [==============================] - 4s 8ms/step - loss: 0.7293 - binary_accuracy: 0.6992 - auc_1: 0.6964 - val_loss: 0.5586 - val_binary_accuracy: 0.7573 - val_auc_1: 0.7780
# Epoch 6/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.6698 - binary_accuracy: 0.7179 - auc_1: 0.7196 - val_loss: 0.5528 - val_binary_accuracy: 0.7560 - val_auc_1: 0.7662
# Epoch 7/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.6329 - binary_accuracy: 0.7265 - auc_1: 0.7303 - val_loss: 0.5567 - val_binary_accuracy: 0.7553 - val_auc_1: 0.7711
# Epoch 8/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.6225 - binary_accuracy: 0.7192 - auc_1: 0.7229 - val_loss: 0.5488 - val_binary_accuracy: 0.7580 - val_auc_1: 0.7653
# Epoch 9/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.6047 - binary_accuracy: 0.7336 - auc_1: 0.7358 - val_loss: 0.5327 - val_binary_accuracy: 0.7613 - val_auc_1: 0.7763
# Epoch 10/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5800 - binary_accuracy: 0.7336 - auc_1: 0.7376 - val_loss: 0.5221 - val_binary_accuracy: 0.7647 - val_auc_1: 0.7765
# Epoch 11/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5586 - binary_accuracy: 0.7376 - auc_1: 0.7506 - val_loss: 0.5304 - val_binary_accuracy: 0.7633 - val_auc_1: 0.7650
# Epoch 12/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5526 - binary_accuracy: 0.7467 - auc_1: 0.7490 - val_loss: 0.5296 - val_binary_accuracy: 0.7667 - val_auc_1: 0.7803
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# Epoch 13/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5357 - binary_accuracy: 0.7568 - auc_1: 0.7657 - val_loss: 0.5223 - val_binary_accuracy: 0.7673 - val_auc_1: 0.7784
# Epoch 14/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5348 - binary_accuracy: 0.7499 - auc_1: 0.7650 - val_loss: 0.5219 - val_binary_accuracy: 0.7593 - val_auc_1: 0.7776
# Epoch 15/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5434 - binary_accuracy: 0.7451 - auc_1: 0.7494 - val_loss: 0.5237 - val_binary_accuracy: 0.7627 - val_auc_1: 0.7816
# Epoch 16/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5278 - binary_accuracy: 0.7561 - auc_1: 0.7704 - val_loss: 0.5258 - val_binary_accuracy: 0.7633 - val_auc_1: 0.7701
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
# Epoch 17/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5227 - binary_accuracy: 0.7599 - auc_1: 0.7688 - val_loss: 0.5218 - val_binary_accuracy: 0.7647 - val_auc_1: 0.7783
# Epoch 18/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5225 - binary_accuracy: 0.7525 - auc_1: 0.7708 - val_loss: 0.5165 - val_binary_accuracy: 0.7587 - val_auc_1: 0.7774
# Epoch 19/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5213 - binary_accuracy: 0.7579 - auc_1: 0.7755 - val_loss: 0.5271 - val_binary_accuracy: 0.7567 - val_auc_1: 0.7749
# Epoch 20/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5146 - binary_accuracy: 0.7604 - auc_1: 0.7762 - val_loss: 0.5138 - val_binary_accuracy: 0.7620 - val_auc_1: 0.7796
# Epoch 21/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5094 - binary_accuracy: 0.7583 - auc_1: 0.7822 - val_loss: 0.5194 - val_binary_accuracy: 0.7593 - val_auc_1: 0.7764
# Epoch 22/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5086 - binary_accuracy: 0.7648 - auc_1: 0.7768 - val_loss: 0.5132 - val_binary_accuracy: 0.7573 - val_auc_1: 0.7806
# Epoch 23/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5071 - binary_accuracy: 0.7617 - auc_1: 0.7824 - val_loss: 0.5263 - val_binary_accuracy: 0.7600 - val_auc_1: 0.7634
# Epoch 24/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5001 - binary_accuracy: 0.7740 - auc_1: 0.7875 - val_loss: 0.5212 - val_binary_accuracy: 0.7613 - val_auc_1: 0.7785
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
# Epoch 25/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5157 - binary_accuracy: 0.7635 - auc_1: 0.7722 - val_loss: 0.5177 - val_binary_accuracy: 0.7667 - val_auc_1: 0.7748
# Epoch 26/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5100 - binary_accuracy: 0.7646 - auc_1: 0.7810 - val_loss: 0.5174 - val_binary_accuracy: 0.7680 - val_auc_1: 0.7756
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.0960000478662555e-05.
# Epoch 27/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5054 - binary_accuracy: 0.7685 - auc_1: 0.7884 - val_loss: 0.5144 - val_binary_accuracy: 0.7633 - val_auc_1: 0.7833
# Epoch 28/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.4985 - binary_accuracy: 0.7701 - auc_1: 0.7881 - val_loss: 0.5146 - val_binary_accuracy: 0.7653 - val_auc_1: 0.7843
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 3.2767999800853435e-05.
# Epoch 29/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.5034 - binary_accuracy: 0.7719 - auc_1: 0.7857 - val_loss: 0.5146 - val_binary_accuracy: 0.7620 - val_auc_1: 0.7831
# Epoch 30/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.4953 - binary_accuracy: 0.7740 - auc_1: 0.7943 - val_loss: 0.5183 - val_binary_accuracy: 0.7620 - val_auc_1: 0.7779
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.6214399258606137e-05.
# Epoch 31/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.4993 - binary_accuracy: 0.7694 - auc_1: 0.7892 - val_loss: 0.5139 - val_binary_accuracy: 0.7633 - val_auc_1: 0.7823
# Epoch 32/100
# 422/422 [==============================] - 3s 8ms/step - loss: 0.4911 - binary_accuracy: 0.7727 - auc_1: 0.7965 - val_loss: 0.5145 - val_binary_accuracy: 0.7693 - val_auc_1: 0.7809
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 2.09715188248083e-05.

# %%
## nn 예측 및 제출 파일 생성
pred = model.predict(X_test)
sample_submssion = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/sample_submission.csv')
sample_submssion['problem'] = pred
sample_submssion.to_csv("/content/drive/MyDrive/Colab/data/LG/xgb_quality_0.808.csv", index = False)
sample_submssion
# Out:
# array([[0.9451776 ],
#        [0.22847222],
#        [0.25630665],
#        ...,
#        [0.23337525],
#        [0.8426967 ],
#        [0.26030147]], dtype=float32)

# %% [markdown]
# ## LGBM

# %%
train_x = X
train_y = problem

print(train_x.shape)
print(train_y.shape)
# Out:
# (15000, 53)
# (15000,)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import precision_recall_curve, auc, recall_score, precision_score

def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score, True

# %%
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'boosting_type' : 'gbdt',
                'objective'     : 'binary',
                'metric'        : 'auc',
                'seed': 1015,
               
                'application': 'binary',
                'max_depth ': 4,
                'is_unbalance': 'true',
                'num_leaves': 31,
                'feature_fraction': 0.9,
                'bagging_fraction': 0.7,
                'bagging_freq': 20,
                'learning_rate': 0.008,
                'verbose': 0
                }
#-------------------------------------------------------------------------------------
# 5 Kfold cross validation
k_fold = KFold(n_splits=5, shuffle=True, random_state=42)
for train_idx, val_idx in k_fold.split(train_x):

    # split train, validation set
    X = train_x[train_idx]
    y = train_y[train_idx]
    valid_x = train_x[val_idx]
    valid_y = train_y[val_idx]

    d_train= lgbm.Dataset(X, y)
    d_val  = lgbm.Dataset(valid_x, valid_y)
    
    #run traning
    model = lgbm.train(
                        params,
                        train_set       = d_train,
                        num_boost_round = 10000,
                        valid_sets      = d_val,
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 500
                       )
    
    # cal valid prediction
    valid_prob = model.predict(valid_x)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's auc: 0.786868	valid_0's pr_auc: 0.776467
# [40]	valid_0's auc: 0.792402	valid_0's pr_auc: 0.780675
# [60]	valid_0's auc: 0.795167	valid_0's pr_auc: 0.782547
# [80]	valid_0's auc: 0.795583	valid_0's pr_auc: 0.783495
# [100]	valid_0's auc: 0.796747	valid_0's pr_auc: 0.783999
# [120]	valid_0's auc: 0.797447	valid_0's pr_auc: 0.786412
# [140]	valid_0's auc: 0.798161	valid_0's pr_auc: 0.787744
# [160]	valid_0's auc: 0.799412	valid_0's pr_auc: 0.790619
# [180]	valid_0's auc: 0.799837	valid_0's pr_auc: 0.791512
# [200]	valid_0's auc: 0.800607	valid_0's pr_auc: 0.792397
# [220]	valid_0's auc: 0.801834	valid_0's pr_auc: 0.793366
# [240]	valid_0's auc: 0.802937	valid_0's pr_auc: 0.795475
# [260]	valid_0's auc: 0.802477	valid_0's pr_auc: 0.796155
# [280]	valid_0's auc: 0.803423	valid_0's pr_auc: 0.796915
# [300]	valid_0's auc: 0.804331	valid_0's pr_auc: 0.797893
# [320]	valid_0's auc: 0.804423	valid_0's pr_auc: 0.798073
# [340]	valid_0's auc: 0.804613	valid_0's pr_auc: 0.797913
# [360]	valid_0's auc: 0.805239	valid_0's pr_auc: 0.798527
# [380]	valid_0's auc: 0.805478	valid_0's pr_auc: 0.797755
# [400]	valid_0's auc: 0.805851	valid_0's pr_auc: 0.798134
# [420]	valid_0's auc: 0.80645	valid_0's pr_auc: 0.798805
# [440]	valid_0's auc: 0.807064	valid_0's pr_auc: 0.799143
# [460]	valid_0's auc: 0.807377	valid_0's pr_auc: 0.79894
# [480]	valid_0's auc: 0.807555	valid_0's pr_auc: 0.799154
# [500]	valid_0's auc: 0.807827	valid_0's pr_auc: 0.799414
# [520]	valid_0's auc: 0.807971	valid_0's pr_auc: 0.799841
# [540]	valid_0's auc: 0.80818	valid_0's pr_auc: 0.801429
# [560]	valid_0's auc: 0.808201	valid_0's pr_auc: 0.801046
# [580]	valid_0's auc: 0.807941	valid_0's pr_auc: 0.801343
# [600]	valid_0's auc: 0.807743	valid_0's pr_auc: 0.801423
# [620]	valid_0's auc: 0.808212	valid_0's pr_auc: 0.801818
# [640]	valid_0's auc: 0.808291	valid_0's pr_auc: 0.80221
# [660]	valid_0's auc: 0.808448	valid_0's pr_auc: 0.802246
# [680]	valid_0's auc: 0.80864	valid_0's pr_auc: 0.802972
# [700]	valid_0's auc: 0.808843	valid_0's pr_auc: 0.803021
# [720]	valid_0's auc: 0.808881	valid_0's pr_auc: 0.803386
# [740]	valid_0's auc: 0.808792	valid_0's pr_auc: 0.803367
# [760]	valid_0's auc: 0.808944	valid_0's pr_auc: 0.803478
# [780]	valid_0's auc: 0.808827	valid_0's pr_auc: 0.803351
# [800]	valid_0's auc: 0.809009	valid_0's pr_auc: 0.803478
# [820]	valid_0's auc: 0.808475	valid_0's pr_auc: 0.803635
# [840]	valid_0's auc: 0.808387	valid_0's pr_auc: 0.803895
# [860]	valid_0's auc: 0.808057	valid_0's pr_auc: 0.803624
# [880]	valid_0's auc: 0.807975	valid_0's pr_auc: 0.803337
# [900]	valid_0's auc: 0.808175	valid_0's pr_auc: 0.803728
# [920]	valid_0's auc: 0.807906	valid_0's pr_auc: 0.803981
# [940]	valid_0's auc: 0.808005	valid_0's pr_auc: 0.804092
# [960]	valid_0's auc: 0.808046	valid_0's pr_auc: 0.804273
# [980]	valid_0's auc: 0.808293	valid_0's pr_auc: 0.804602
# [1000]	valid_0's auc: 0.808085	valid_0's pr_auc: 0.804306
# [1020]	valid_0's auc: 0.80794	valid_0's pr_auc: 0.804348
# [1040]	valid_0's auc: 0.807583	valid_0's pr_auc: 0.804188
# [1060]	valid_0's auc: 0.807452	valid_0's pr_auc: 0.804254
# [1080]	valid_0's auc: 0.807421	valid_0's pr_auc: 0.804326
# [1100]	valid_0's auc: 0.807374	valid_0's pr_auc: 0.804163
# [1120]	valid_0's auc: 0.807456	valid_0's pr_auc: 0.804226
# [1140]	valid_0's auc: 0.807491	valid_0's pr_auc: 0.804476
# [1160]	valid_0's auc: 0.807253	valid_0's pr_auc: 0.804382
# [1180]	valid_0's auc: 0.807434	valid_0's pr_auc: 0.804684
# [1200]	valid_0's auc: 0.807555	valid_0's pr_auc: 0.804974
# [1220]	valid_0's auc: 0.807443	valid_0's pr_auc: 0.80481
# [1240]	valid_0's auc: 0.807413	valid_0's pr_auc: 0.804937
# [1260]	valid_0's auc: 0.80768	valid_0's pr_auc: 0.805232
# [1280]	valid_0's auc: 0.807454	valid_0's pr_auc: 0.805101
# [1300]	valid_0's auc: 0.807478	valid_0's pr_auc: 0.80526
# Early stopping, best iteration is:
# [802]	valid_0's auc: 0.809018	valid_0's pr_auc: 0.803497
# ==========================================================
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's auc: 0.786189	valid_0's pr_auc: 0.311295
# [40]	valid_0's auc: 0.796568	valid_0's pr_auc: 0.32086
# [60]	valid_0's auc: 0.800615	valid_0's pr_auc: 0.322572
# [80]	valid_0's auc: 0.803496	valid_0's pr_auc: 0.336448
# [100]	valid_0's auc: 0.805252	valid_0's pr_auc: 0.331973
# [120]	valid_0's auc: 0.807721	valid_0's pr_auc: 0.339263
# [140]	valid_0's auc: 0.808729	valid_0's pr_auc: 0.341863
# [160]	valid_0's auc: 0.809245	valid_0's pr_auc: 0.342174
# [180]	valid_0's auc: 0.811673	valid_0's pr_auc: 0.343755
# [200]	valid_0's auc: 0.811638	valid_0's pr_auc: 0.343048
# [220]	valid_0's auc: 0.812964	valid_0's pr_auc: 0.349051
# [240]	valid_0's auc: 0.812818	valid_0's pr_auc: 0.357023
# [260]	valid_0's auc: 0.813256	valid_0's pr_auc: 0.358719
# [280]	valid_0's auc: 0.813722	valid_0's pr_auc: 0.360651
# [300]	valid_0's auc: 0.814302	valid_0's pr_auc: 0.356862
# [320]	valid_0's auc: 0.815421	valid_0's pr_auc: 0.340976
# [340]	valid_0's auc: 0.814036	valid_0's pr_auc: 0.339923
# [360]	valid_0's auc: 0.814646	valid_0's pr_auc: 0.350035
# [380]	valid_0's auc: 0.813962	valid_0's pr_auc: 0.354439
# [400]	valid_0's auc: 0.813791	valid_0's pr_auc: 0.350473
# [420]	valid_0's auc: 0.813302	valid_0's pr_auc: 0.357266
# [440]	valid_0's auc: 0.813808	valid_0's pr_auc: 0.354258
# [460]	valid_0's auc: 0.814383	valid_0's pr_auc: 0.349412
# [480]	valid_0's auc: 0.815171	valid_0's pr_auc: 0.354947
# [500]	valid_0's auc: 0.815442	valid_0's pr_auc: 0.363098
# [520]	valid_0's auc: 0.815545	valid_0's pr_auc: 0.354195
# [540]	valid_0's auc: 0.815541	valid_0's pr_auc: 0.356852
# [560]	valid_0's auc: 0.816135	valid_0's pr_auc: 0.358966
# [580]	valid_0's auc: 0.816164	valid_0's pr_auc: 0.363393
# [600]	valid_0's auc: 0.815851	valid_0's pr_auc: 0.35943
# [620]	valid_0's auc: 0.815508	valid_0's pr_auc: 0.361764
# [640]	valid_0's auc: 0.814901	valid_0's pr_auc: 0.360565
# [660]	valid_0's auc: 0.814628	valid_0's pr_auc: 0.358192
# [680]	valid_0's auc: 0.814613	valid_0's pr_auc: 0.355892
# [700]	valid_0's auc: 0.814823	valid_0's pr_auc: 0.358078
# [720]	valid_0's auc: 0.815057	valid_0's pr_auc: 0.359555
# [740]	valid_0's auc: 0.814747	valid_0's pr_auc: 0.357721
# [760]	valid_0's auc: 0.814622	valid_0's pr_auc: 0.351163
# [780]	valid_0's auc: 0.814883	valid_0's pr_auc: 0.352284
# Early stopping, best iteration is:
# [283]	valid_0's auc: 0.813938	valid_0's pr_auc: 0.364896
# ==========================================================
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's auc: 0.755181	valid_0's pr_auc: 0.353508
# [40]	valid_0's auc: 0.765203	valid_0's pr_auc: 0.362159
# [60]	valid_0's auc: 0.768053	valid_0's pr_auc: 0.364106
# [80]	valid_0's auc: 0.773258	valid_0's pr_auc: 0.367929
# [100]	valid_0's auc: 0.775718	valid_0's pr_auc: 0.369534
# [120]	valid_0's auc: 0.776448	valid_0's pr_auc: 0.384104
# [140]	valid_0's auc: 0.778435	valid_0's pr_auc: 0.387846
# [160]	valid_0's auc: 0.781039	valid_0's pr_auc: 0.388435
# [180]	valid_0's auc: 0.782916	valid_0's pr_auc: 0.391711
# [200]	valid_0's auc: 0.78496	valid_0's pr_auc: 0.394056
# [220]	valid_0's auc: 0.785974	valid_0's pr_auc: 0.397615
# [240]	valid_0's auc: 0.785684	valid_0's pr_auc: 0.401023
# [260]	valid_0's auc: 0.785606	valid_0's pr_auc: 0.40237
# [280]	valid_0's auc: 0.787734	valid_0's pr_auc: 0.405065
# [300]	valid_0's auc: 0.787331	valid_0's pr_auc: 0.406725
# [320]	valid_0's auc: 0.78731	valid_0's pr_auc: 0.414232
# [340]	valid_0's auc: 0.78635	valid_0's pr_auc: 0.415683
# [360]	valid_0's auc: 0.786349	valid_0's pr_auc: 0.410598
# [380]	valid_0's auc: 0.786404	valid_0's pr_auc: 0.403511
# [400]	valid_0's auc: 0.787237	valid_0's pr_auc: 0.404217
# [420]	valid_0's auc: 0.787458	valid_0's pr_auc: 0.407772
# [440]	valid_0's auc: 0.786781	valid_0's pr_auc: 0.409951
# [460]	valid_0's auc: 0.787806	valid_0's pr_auc: 0.408369
# [480]	valid_0's auc: 0.788842	valid_0's pr_auc: 0.403732
# [500]	valid_0's auc: 0.788391	valid_0's pr_auc: 0.413059
# [520]	valid_0's auc: 0.788584	valid_0's pr_auc: 0.412031
# [540]	valid_0's auc: 0.787659	valid_0's pr_auc: 0.411145
# [560]	valid_0's auc: 0.788175	valid_0's pr_auc: 0.410573
# [580]	valid_0's auc: 0.788776	valid_0's pr_auc: 0.413164
# [600]	valid_0's auc: 0.789181	valid_0's pr_auc: 0.413399
# [620]	valid_0's auc: 0.789974	valid_0's pr_auc: 0.412662
# [640]	valid_0's auc: 0.790222	valid_0's pr_auc: 0.411005
# [660]	valid_0's auc: 0.790419	valid_0's pr_auc: 0.411752
# [680]	valid_0's auc: 0.789883	valid_0's pr_auc: 0.411434
# [700]	valid_0's auc: 0.790012	valid_0's pr_auc: 0.414242
# [720]	valid_0's auc: 0.789457	valid_0's pr_auc: 0.414249
# [740]	valid_0's auc: 0.789191	valid_0's pr_auc: 0.414007
# [760]	valid_0's auc: 0.789231	valid_0's pr_auc: 0.412012
# [780]	valid_0's auc: 0.788749	valid_0's pr_auc: 0.41385
# [800]	valid_0's auc: 0.789307	valid_0's pr_auc: 0.413824
# [820]	valid_0's auc: 0.788526	valid_0's pr_auc: 0.413347
# Early stopping, best iteration is:
# [327]	valid_0's auc: 0.787117	valid_0's pr_auc: 0.416939
# ==========================================================
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's auc: 0.806672	valid_0's pr_auc: 0.491244
# [40]	valid_0's auc: 0.807797	valid_0's pr_auc: 0.505114
# [60]	valid_0's auc: 0.81097	valid_0's pr_auc: 0.50801
# [80]	valid_0's auc: 0.812735	valid_0's pr_auc: 0.510399
# [100]	valid_0's auc: 0.811991	valid_0's pr_auc: 0.512346
# [120]	valid_0's auc: 0.812888	valid_0's pr_auc: 0.513678
# [140]	valid_0's auc: 0.813765	valid_0's pr_auc: 0.514451
# [160]	valid_0's auc: 0.813611	valid_0's pr_auc: 0.521923
# [180]	valid_0's auc: 0.813443	valid_0's pr_auc: 0.521664
# [200]	valid_0's auc: 0.81374	valid_0's pr_auc: 0.519868
# [220]	valid_0's auc: 0.814216	valid_0's pr_auc: 0.522771
# [240]	valid_0's auc: 0.814486	valid_0's pr_auc: 0.52599
# [260]	valid_0's auc: 0.814253	valid_0's pr_auc: 0.526147
# [280]	valid_0's auc: 0.815097	valid_0's pr_auc: 0.527966
# [300]	valid_0's auc: 0.815518	valid_0's pr_auc: 0.534397
# [320]	valid_0's auc: 0.815783	valid_0's pr_auc: 0.533445
# [340]	valid_0's auc: 0.815139	valid_0's pr_auc: 0.530513
# [360]	valid_0's auc: 0.815672	valid_0's pr_auc: 0.538245
# [380]	valid_0's auc: 0.815539	valid_0's pr_auc: 0.536357
# [400]	valid_0's auc: 0.815165	valid_0's pr_auc: 0.536575
# [420]	valid_0's auc: 0.815553	valid_0's pr_auc: 0.533043
# [440]	valid_0's auc: 0.816279	valid_0's pr_auc: 0.535259
# [460]	valid_0's auc: 0.815819	valid_0's pr_auc: 0.532349
# [480]	valid_0's auc: 0.816057	valid_0's pr_auc: 0.533065
# [500]	valid_0's auc: 0.816561	valid_0's pr_auc: 0.536307
# [520]	valid_0's auc: 0.81617	valid_0's pr_auc: 0.535005
# [540]	valid_0's auc: 0.815945	valid_0's pr_auc: 0.532854
# [560]	valid_0's auc: 0.815758	valid_0's pr_auc: 0.534578
# [580]	valid_0's auc: 0.815828	valid_0's pr_auc: 0.535185
# [600]	valid_0's auc: 0.81596	valid_0's pr_auc: 0.539309
# [620]	valid_0's auc: 0.816413	valid_0's pr_auc: 0.538298
# [640]	valid_0's auc: 0.816327	valid_0's pr_auc: 0.539414
# [660]	valid_0's auc: 0.816555	valid_0's pr_auc: 0.538804
# [680]	valid_0's auc: 0.816378	valid_0's pr_auc: 0.540838
# [700]	valid_0's auc: 0.815781	valid_0's pr_auc: 0.53856
# [720]	valid_0's auc: 0.815856	valid_0's pr_auc: 0.539205
# [740]	valid_0's auc: 0.815666	valid_0's pr_auc: 0.540086
# [760]	valid_0's auc: 0.815569	valid_0's pr_auc: 0.540192
# [780]	valid_0's auc: 0.816083	valid_0's pr_auc: 0.540882
# [800]	valid_0's auc: 0.815554	valid_0's pr_auc: 0.539685
# [820]	valid_0's auc: 0.815748	valid_0's pr_auc: 0.538597
# [840]	valid_0's auc: 0.815553	valid_0's pr_auc: 0.5397
# [860]	valid_0's auc: 0.815764	valid_0's pr_auc: 0.539538
# [880]	valid_0's auc: 0.815746	valid_0's pr_auc: 0.540959
# [900]	valid_0's auc: 0.815459	valid_0's pr_auc: 0.539263
# [920]	valid_0's auc: 0.815421	valid_0's pr_auc: 0.539838
# [940]	valid_0's auc: 0.815286	valid_0's pr_auc: 0.540031
# [960]	valid_0's auc: 0.815114	valid_0's pr_auc: 0.539336
# [980]	valid_0's auc: 0.814752	valid_0's pr_auc: 0.540343
# [1000]	valid_0's auc: 0.814818	valid_0's pr_auc: 0.539836
# [1020]	valid_0's auc: 0.814712	valid_0's pr_auc: 0.539085
# [1040]	valid_0's auc: 0.814564	valid_0's pr_auc: 0.539293
# [1060]	valid_0's auc: 0.814879	valid_0's pr_auc: 0.541062
# [1080]	valid_0's auc: 0.814983	valid_0's pr_auc: 0.541627
# [1100]	valid_0's auc: 0.81508	valid_0's pr_auc: 0.541322
# [1120]	valid_0's auc: 0.814902	valid_0's pr_auc: 0.541257
# [1140]	valid_0's auc: 0.814663	valid_0's pr_auc: 0.540349
# Early stopping, best iteration is:
# [659]	valid_0's auc: 0.816572	valid_0's pr_auc: 0.538915
# ==========================================================
# Training until validation scores don't improve for 500 rounds.
# [20]	valid_0's auc: 0.800304	valid_0's pr_auc: 0.971619
# [40]	valid_0's auc: 0.801268	valid_0's pr_auc: 0.971524
# [60]	valid_0's auc: 0.802399	valid_0's pr_auc: 0.971687
# [80]	valid_0's auc: 0.803929	valid_0's pr_auc: 0.97193
# [100]	valid_0's auc: 0.804841	valid_0's pr_auc: 0.972126
# [120]	valid_0's auc: 0.806715	valid_0's pr_auc: 0.972392
# [140]	valid_0's auc: 0.804768	valid_0's pr_auc: 0.972125
# [160]	valid_0's auc: 0.807952	valid_0's pr_auc: 0.973253
# [180]	valid_0's auc: 0.808179	valid_0's pr_auc: 0.973373
# [200]	valid_0's auc: 0.809214	valid_0's pr_auc: 0.973463
# [220]	valid_0's auc: 0.808658	valid_0's pr_auc: 0.973364
# [240]	valid_0's auc: 0.809432	valid_0's pr_auc: 0.973535
# [260]	valid_0's auc: 0.810478	valid_0's pr_auc: 0.973667
# [280]	valid_0's auc: 0.810687	valid_0's pr_auc: 0.973617
# [300]	valid_0's auc: 0.811214	valid_0's pr_auc: 0.973826
# [320]	valid_0's auc: 0.811621	valid_0's pr_auc: 0.973905
# [340]	valid_0's auc: 0.812856	valid_0's pr_auc: 0.973959
# [360]	valid_0's auc: 0.812766	valid_0's pr_auc: 0.974501
# [380]	valid_0's auc: 0.812848	valid_0's pr_auc: 0.97453
# [400]	valid_0's auc: 0.81242	valid_0's pr_auc: 0.974237
# [420]	valid_0's auc: 0.811686	valid_0's pr_auc: 0.974137
# [440]	valid_0's auc: 0.811658	valid_0's pr_auc: 0.974137
# [460]	valid_0's auc: 0.811987	valid_0's pr_auc: 0.974304
# [480]	valid_0's auc: 0.812225	valid_0's pr_auc: 0.974305
# [500]	valid_0's auc: 0.81255	valid_0's pr_auc: 0.974407
# [520]	valid_0's auc: 0.812311	valid_0's pr_auc: 0.974578
# [540]	valid_0's auc: 0.812941	valid_0's pr_auc: 0.974596
# [560]	valid_0's auc: 0.812479	valid_0's pr_auc: 0.974443
# [580]	valid_0's auc: 0.812685	valid_0's pr_auc: 0.974761
# [600]	valid_0's auc: 0.813916	valid_0's pr_auc: 0.975074
# [620]	valid_0's auc: 0.813852	valid_0's pr_auc: 0.975461
# [640]	valid_0's auc: 0.813544	valid_0's pr_auc: 0.975448
# [660]	valid_0's auc: 0.814018	valid_0's pr_auc: 0.97549
# [680]	valid_0's auc: 0.814622	valid_0's pr_auc: 0.975699
# [700]	valid_0's auc: 0.815077	valid_0's pr_auc: 0.975861
# [720]	valid_0's auc: 0.814426	valid_0's pr_auc: 0.975745
# [740]	valid_0's auc: 0.814172	valid_0's pr_auc: 0.975779
# [760]	valid_0's auc: 0.814998	valid_0's pr_auc: 0.976094
# [780]	valid_0's auc: 0.815359	valid_0's pr_auc: 0.976159
# [800]	valid_0's auc: 0.814583	valid_0's pr_auc: 0.976088
# [820]	valid_0's auc: 0.81462	valid_0's pr_auc: 0.976088
# [840]	valid_0's auc: 0.814305	valid_0's pr_auc: 0.976154
# [860]	valid_0's auc: 0.814511	valid_0's pr_auc: 0.976227
# [880]	valid_0's auc: 0.813795	valid_0's pr_auc: 0.976101
# [900]	valid_0's auc: 0.813925	valid_0's pr_auc: 0.976097
# [920]	valid_0's auc: 0.813633	valid_0's pr_auc: 0.976116
# [940]	valid_0's auc: 0.813974	valid_0's pr_auc: 0.976233
# [960]	valid_0's auc: 0.813588	valid_0's pr_auc: 0.97618
# [980]	valid_0's auc: 0.813409	valid_0's pr_auc: 0.976165
# [1000]	valid_0's auc: 0.813594	valid_0's pr_auc: 0.976234
# [1020]	valid_0's auc: 0.813381	valid_0's pr_auc: 0.976247
# [1040]	valid_0's auc: 0.813517	valid_0's pr_auc: 0.976282
# [1060]	valid_0's auc: 0.81405	valid_0's pr_auc: 0.976352
# [1080]	valid_0's auc: 0.814467	valid_0's pr_auc: 0.97646
# [1100]	valid_0's auc: 0.814488	valid_0's pr_auc: 0.976507
# [1120]	valid_0's auc: 0.813758	valid_0's pr_auc: 0.976419
# [1140]	valid_0's auc: 0.813339	valid_0's pr_auc: 0.976365
# [1160]	valid_0's auc: 0.81294	valid_0's pr_auc: 0.976336
# [1180]	valid_0's auc: 0.812465	valid_0's pr_auc: 0.976305
# [1200]	valid_0's auc: 0.81182	valid_0's pr_auc: 0.976202
# [1220]	valid_0's auc: 0.811629	valid_0's pr_auc: 0.976191
# [1240]	valid_0's auc: 0.811401	valid_0's pr_auc: 0.976185
# [1260]	valid_0's auc: 0.810508	valid_0's pr_auc: 0.976045
# [1280]	valid_0's auc: 0.810683	valid_0's pr_auc: 0.976106
# Early stopping, best iteration is:
# [780]	valid_0's auc: 0.815359	valid_0's pr_auc: 0.976159
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8084007994499858

# %%
pred_y_list = []
for model in models:
    pred_y = model.predict(X_test)
    pred_y_list.append(pred_y.reshape(-1,1))
    
lgbm_pred_ensemble = np.mean(pred_y_list, axis = 0)
lgbm_pred_ensemble
# Out:
# array([[0.93240288],
#        [0.35473051],
#        [0.45394521],
#        ...,
#        [0.71587332],
#        [0.90518455],
#        [0.55281239]])

# %%
sample_submssion = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/sample_submission.csv')
sample_submssion['problem'] = lgbm_pred_ensemble.reshape(-1)
sample_submssion.to_csv("/content/drive/MyDrive/Colab/data/LG/xgb_quality_0.808.csv", index = False)
sample_submssion

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

def f_pr_auc(probas_pred, y_true):
    labels=y_true.get_label()
    p, r, _ = precision_recall_curve(labels, probas_pred)
    score=auc(r,p) 
    return "pr_auc", score
#-------------------------------------------------------------------------------------
models     = []
recalls    = []
precisions = []
auc_scores   = []
threshold = 0.5
# 파라미터 설정
params =      {
                'boosting_type' : 'gbdt',
                'objective'     : 'binary:logistic',
                'eval_metric'        : 'auc',
                'seed': 1015,
               
                'application': 'binary',
                'max_depth ': 4,
                'is_unbalance': 'true',
                'num_leaves': 50,
                'feature_fraction': 0.9,
                'bagging_fraction': 0.7,
                'bagging_freq': 20,
                'learning_rate': 0.008,
                'verbose': 0
                }
#-------------------------------------------------------------------------------------
# 5 Kfold cross validation
k_fold = KFold(n_splits=5, shuffle=True, random_state=42)
for train_idx, val_idx in k_fold.split(x_train):

    # split train, validation set
    X = x_train[train_idx]
    y = y_train[train_idx]
    valid_x = x_train[val_idx]
    valid_y = y_train[val_idx]

    d_train= xgb.DMatrix(X, y)
    d_val  = xgb.DMatrix(valid_x, valid_y)
    
    d_valid_x = xgb.DMatrix(valid_x)

    #run traning
    model = xgb.train(
                        params,
                        dtrain       = d_train,
                        num_boost_round = 10000,
                        evals      = [(d_train, 'train'), (d_val, 'eval')],
                        feval           = f_pr_auc,
                        verbose_eval    = 20, 
                        early_stopping_rounds = 500
                       )
    
    # # cal valid prediction
    valid_prob = model.predict(d_valid_x)
    # print(valid_prob)
    valid_pred = np.where(valid_prob > threshold, 1, 0)
    
    # # cal scores
    recall    = recall_score(    valid_y, valid_pred)
    precision = precision_score( valid_y, valid_pred)
    auc_score = roc_auc_score(   valid_y, valid_prob)

    # # append scores
    models.append(model)
    recalls.append(recall)
    precisions.append(precision)
    auc_scores.append(auc_score)

    print('==========================================================')
# Out:
# [0]	train-auc:0.781301	eval-auc:0.769638	train-pr_auc:0.712208	eval-pr_auc:0.687022
# Multiple eval metrics have been passed: 'eval-pr_auc' will be used for early stopping.
#
# Will train until eval-pr_auc hasn't improved in 500 rounds.
# [20]	train-auc:0.800088	eval-auc:0.789103	train-pr_auc:0.727285	eval-pr_auc:0.705993
# [40]	train-auc:0.80736	eval-auc:0.797348	train-pr_auc:0.736919	eval-pr_auc:0.723745
# [60]	train-auc:0.816431	eval-auc:0.803823	train-pr_auc:0.747246	eval-pr_auc:0.727326
# [80]	train-auc:0.820771	eval-auc:0.806752	train-pr_auc:0.752822	eval-pr_auc:0.733627
# [100]	train-auc:0.823851	eval-auc:0.808373	train-pr_auc:0.757416	eval-pr_auc:0.734394
# [120]	train-auc:0.826386	eval-auc:0.809581	train-pr_auc:0.76094	eval-pr_auc:0.736054
# [140]	train-auc:0.828732	eval-auc:0.810887	train-pr_auc:0.764776	eval-pr_auc:0.738629
# [160]	train-auc:0.831166	eval-auc:0.812092	train-pr_auc:0.768462	eval-pr_auc:0.740524
# [180]	train-auc:0.833767	eval-auc:0.813347	train-pr_auc:0.772261	eval-pr_auc:0.742021
# [200]	train-auc:0.836068	eval-auc:0.814537	train-pr_auc:0.775979	eval-pr_auc:0.74255
# [220]	train-auc:0.837974	eval-auc:0.815367	train-pr_auc:0.778844	eval-pr_auc:0.742167
# [240]	train-auc:0.839818	eval-auc:0.816106	train-pr_auc:0.781579	eval-pr_auc:0.743471
# [260]	train-auc:0.841521	eval-auc:0.816908	train-pr_auc:0.784057	eval-pr_auc:0.74467
# [280]	train-auc:0.843284	eval-auc:0.818016	train-pr_auc:0.787038	eval-pr_auc:0.745957
# [300]	train-auc:0.844992	eval-auc:0.81864	train-pr_auc:0.790021	eval-pr_auc:0.745975
# [320]	train-auc:0.846457	eval-auc:0.819346	train-pr_auc:0.792432	eval-pr_auc:0.747043
# [340]	train-auc:0.847627	eval-auc:0.819954	train-pr_auc:0.794396	eval-pr_auc:0.747769
# [360]	train-auc:0.848999	eval-auc:0.820421	train-pr_auc:0.796795	eval-pr_auc:0.748172
# [380]	train-auc:0.850853	eval-auc:0.820879	train-pr_auc:0.799388	eval-pr_auc:0.74844
# [400]	train-auc:0.852674	eval-auc:0.821011	train-pr_auc:0.801866	eval-pr_auc:0.748819
# [420]	train-auc:0.854312	eval-auc:0.821455	train-pr_auc:0.804158	eval-pr_auc:0.749588
# [440]	train-auc:0.855603	eval-auc:0.821536	train-pr_auc:0.80585	eval-pr_auc:0.750827
# [460]	train-auc:0.856756	eval-auc:0.822051	train-pr_auc:0.807407	eval-pr_auc:0.751902
# [480]	train-auc:0.858649	eval-auc:0.822314	train-pr_auc:0.809979	eval-pr_auc:0.752825
# [500]	train-auc:0.860248	eval-auc:0.822522	train-pr_auc:0.812187	eval-pr_auc:0.753541
# Stopping. Best iteration:
# [0]	train-auc:0.781301	eval-auc:0.769638	train-pr_auc:0.712208	eval-pr_auc:0.687022
#
# ==========================================================
# [0]	train-auc:0.778748	eval-auc:0.764921	train-pr_auc:0.717074	eval-pr_auc:0.649902
# Multiple eval metrics have been passed: 'eval-pr_auc' will be used for early stopping.
#
# Will train until eval-pr_auc hasn't improved in 500 rounds.
# [20]	train-auc:0.800642	eval-auc:0.77839	train-pr_auc:0.734694	eval-pr_auc:0.664856
# [40]	train-auc:0.805808	eval-auc:0.779691	train-pr_auc:0.743138	eval-pr_auc:0.665094
# [60]	train-auc:0.814694	eval-auc:0.785994	train-pr_auc:0.751124	eval-pr_auc:0.676058
# [80]	train-auc:0.821229	eval-auc:0.792853	train-pr_auc:0.759053	eval-pr_auc:0.683462
# [100]	train-auc:0.825936	eval-auc:0.797019	train-pr_auc:0.765046	eval-pr_auc:0.682936
# [120]	train-auc:0.828897	eval-auc:0.799242	train-pr_auc:0.769454	eval-pr_auc:0.685349
# [140]	train-auc:0.830817	eval-auc:0.801307	train-pr_auc:0.77276	eval-pr_auc:0.687824
# [160]	train-auc:0.832571	eval-auc:0.802263	train-pr_auc:0.776326	eval-pr_auc:0.690024
# [180]	train-auc:0.834024	eval-auc:0.803046	train-pr_auc:0.778648	eval-pr_auc:0.692456
# [200]	train-auc:0.835643	eval-auc:0.80428	train-pr_auc:0.781237	eval-pr_auc:0.69477
# [220]	train-auc:0.837446	eval-auc:0.80535	train-pr_auc:0.783681	eval-pr_auc:0.696052
# [240]	train-auc:0.839171	eval-auc:0.806257	train-pr_auc:0.786152	eval-pr_auc:0.698106
# [260]	train-auc:0.840654	eval-auc:0.806839	train-pr_auc:0.788285	eval-pr_auc:0.699657
# [280]	train-auc:0.842254	eval-auc:0.807436	train-pr_auc:0.790585	eval-pr_auc:0.702624
# [300]	train-auc:0.84449	eval-auc:0.808496	train-pr_auc:0.793911	eval-pr_auc:0.704369
# [320]	train-auc:0.846423	eval-auc:0.809368	train-pr_auc:0.797119	eval-pr_auc:0.704526
# [340]	train-auc:0.848338	eval-auc:0.809997	train-pr_auc:0.799849	eval-pr_auc:0.704417
# [360]	train-auc:0.850633	eval-auc:0.810761	train-pr_auc:0.802845	eval-pr_auc:0.70439
# [380]	train-auc:0.852473	eval-auc:0.81105	train-pr_auc:0.805269	eval-pr_auc:0.704018
# [400]	train-auc:0.853913	eval-auc:0.811124	train-pr_auc:0.807407	eval-pr_auc:0.703192
# [420]	train-auc:0.855188	eval-auc:0.811472	train-pr_auc:0.809236	eval-pr_auc:0.703965
# [440]	train-auc:0.856693	eval-auc:0.811587	train-pr_auc:0.811326	eval-pr_auc:0.704646
# [460]	train-auc:0.857951	eval-auc:0.811769	train-pr_auc:0.81312	eval-pr_auc:0.70503
# [480]	train-auc:0.859339	eval-auc:0.811968	train-pr_auc:0.815074	eval-pr_auc:0.70542
# [500]	train-auc:0.860571	eval-auc:0.812128	train-pr_auc:0.816825	eval-pr_auc:0.706587
# Stopping. Best iteration:
# [0]	train-auc:0.778748	eval-auc:0.764921	train-pr_auc:0.717074	eval-pr_auc:0.649902
#
# ==========================================================
# [0]	train-auc:0.787643	eval-auc:0.744202	train-pr_auc:0.718652	eval-pr_auc:0.651673
# Multiple eval metrics have been passed: 'eval-pr_auc' will be used for early stopping.
#
# Will train until eval-pr_auc hasn't improved in 500 rounds.
# [20]	train-auc:0.803106	eval-auc:0.755676	train-pr_auc:0.735746	eval-pr_auc:0.664052
# [40]	train-auc:0.810395	eval-auc:0.761876	train-pr_auc:0.74389	eval-pr_auc:0.674778
# [60]	train-auc:0.821061	eval-auc:0.768587	train-pr_auc:0.75573	eval-pr_auc:0.683556
# [80]	train-auc:0.827273	eval-auc:0.773807	train-pr_auc:0.762928	eval-pr_auc:0.68763
# [100]	train-auc:0.831253	eval-auc:0.776351	train-pr_auc:0.769125	eval-pr_auc:0.688021
# [120]	train-auc:0.833865	eval-auc:0.77842	train-pr_auc:0.773852	eval-pr_auc:0.689392
# [140]	train-auc:0.836145	eval-auc:0.779741	train-pr_auc:0.777461	eval-pr_auc:0.694428
# [160]	train-auc:0.838314	eval-auc:0.780859	train-pr_auc:0.780465	eval-pr_auc:0.696311
# [180]	train-auc:0.8404	eval-auc:0.781812	train-pr_auc:0.783943	eval-pr_auc:0.696345
# [200]	train-auc:0.842337	eval-auc:0.782674	train-pr_auc:0.786837	eval-pr_auc:0.696467
# [220]	train-auc:0.843877	eval-auc:0.78346	train-pr_auc:0.789278	eval-pr_auc:0.696821
# [240]	train-auc:0.845514	eval-auc:0.784217	train-pr_auc:0.791574	eval-pr_auc:0.696819
# [260]	train-auc:0.847297	eval-auc:0.784975	train-pr_auc:0.793864	eval-pr_auc:0.696883
# [280]	train-auc:0.849248	eval-auc:0.785632	train-pr_auc:0.796763	eval-pr_auc:0.697679
# [300]	train-auc:0.851	eval-auc:0.786148	train-pr_auc:0.79939	eval-pr_auc:0.698779
# [320]	train-auc:0.852802	eval-auc:0.786226	train-pr_auc:0.801992	eval-pr_auc:0.699025
# [340]	train-auc:0.855016	eval-auc:0.786275	train-pr_auc:0.805131	eval-pr_auc:0.699145
# [360]	train-auc:0.856778	eval-auc:0.786546	train-pr_auc:0.807869	eval-pr_auc:0.699819
# [380]	train-auc:0.858561	eval-auc:0.786644	train-pr_auc:0.810578	eval-pr_auc:0.700356
# [400]	train-auc:0.86013	eval-auc:0.787058	train-pr_auc:0.812919	eval-pr_auc:0.701345
# [420]	train-auc:0.861554	eval-auc:0.787227	train-pr_auc:0.814995	eval-pr_auc:0.70177
# [440]	train-auc:0.862758	eval-auc:0.787554	train-pr_auc:0.816832	eval-pr_auc:0.702208
# [460]	train-auc:0.864149	eval-auc:0.787768	train-pr_auc:0.818743	eval-pr_auc:0.702812
# [480]	train-auc:0.865463	eval-auc:0.788155	train-pr_auc:0.820421	eval-pr_auc:0.703663
# [500]	train-auc:0.866723	eval-auc:0.788285	train-pr_auc:0.822219	eval-pr_auc:0.703696
# Stopping. Best iteration:
# [1]	train-auc:0.787655	eval-auc:0.745093	train-pr_auc:0.720276	eval-pr_auc:0.65143
#
# ==========================================================
# [0]	train-auc:0.78292	eval-auc:0.749372	train-pr_auc:0.72048	eval-pr_auc:0.659607
# Multiple eval metrics have been passed: 'eval-pr_auc' will be used for early stopping.
#
# Will train until eval-pr_auc hasn't improved in 500 rounds.
# [20]	train-auc:0.808762	eval-auc:0.777498	train-pr_auc:0.737295	eval-pr_auc:0.691447
# [40]	train-auc:0.817032	eval-auc:0.786006	train-pr_auc:0.747585	eval-pr_auc:0.705534
# [60]	train-auc:0.823013	eval-auc:0.790392	train-pr_auc:0.75531	eval-pr_auc:0.70928
# [80]	train-auc:0.827353	eval-auc:0.793125	train-pr_auc:0.76235	eval-pr_auc:0.710451
# [100]	train-auc:0.830263	eval-auc:0.79416	train-pr_auc:0.767803	eval-pr_auc:0.711411
# [120]	train-auc:0.832406	eval-auc:0.795003	train-pr_auc:0.772564	eval-pr_auc:0.711693
# [140]	train-auc:0.8343	eval-auc:0.795745	train-pr_auc:0.775486	eval-pr_auc:0.713586
# [160]	train-auc:0.836219	eval-auc:0.796844	train-pr_auc:0.778213	eval-pr_auc:0.714465
# [180]	train-auc:0.83851	eval-auc:0.798603	train-pr_auc:0.781587	eval-pr_auc:0.716365
# [200]	train-auc:0.839975	eval-auc:0.799226	train-pr_auc:0.784076	eval-pr_auc:0.715975
# [220]	train-auc:0.841313	eval-auc:0.799619	train-pr_auc:0.78677	eval-pr_auc:0.716018
# [240]	train-auc:0.843017	eval-auc:0.800125	train-pr_auc:0.789751	eval-pr_auc:0.716477
# [260]	train-auc:0.844784	eval-auc:0.800488	train-pr_auc:0.792668	eval-pr_auc:0.71641
# [280]	train-auc:0.846599	eval-auc:0.801011	train-pr_auc:0.795548	eval-pr_auc:0.716832
# [300]	train-auc:0.848486	eval-auc:0.801084	train-pr_auc:0.798481	eval-pr_auc:0.716553
# [320]	train-auc:0.850509	eval-auc:0.801299	train-pr_auc:0.801494	eval-pr_auc:0.716096
# [340]	train-auc:0.852869	eval-auc:0.801648	train-pr_auc:0.805166	eval-pr_auc:0.715734
# [360]	train-auc:0.854545	eval-auc:0.801987	train-pr_auc:0.807972	eval-pr_auc:0.715226
# [380]	train-auc:0.855977	eval-auc:0.802314	train-pr_auc:0.810212	eval-pr_auc:0.715575
# [400]	train-auc:0.857573	eval-auc:0.802447	train-pr_auc:0.812605	eval-pr_auc:0.71532
# [420]	train-auc:0.858994	eval-auc:0.802538	train-pr_auc:0.814681	eval-pr_auc:0.714715
# [440]	train-auc:0.860408	eval-auc:0.802816	train-pr_auc:0.816658	eval-pr_auc:0.714572
# [460]	train-auc:0.861845	eval-auc:0.803129	train-pr_auc:0.818604	eval-pr_auc:0.715143
# [480]	train-auc:0.86345	eval-auc:0.803484	train-pr_auc:0.820669	eval-pr_auc:0.714964
# [500]	train-auc:0.86459	eval-auc:0.803824	train-pr_auc:0.822172	eval-pr_auc:0.715203
# Stopping. Best iteration:
# [0]	train-auc:0.78292	eval-auc:0.749372	train-pr_auc:0.72048	eval-pr_auc:0.659607
#
# ==========================================================
# [0]	train-auc:0.781464	eval-auc:0.765987	train-pr_auc:0.71533	eval-pr_auc:0.662209
# Multiple eval metrics have been passed: 'eval-pr_auc' will be used for early stopping.
#
# Will train until eval-pr_auc hasn't improved in 500 rounds.
# [20]	train-auc:0.796763	eval-auc:0.780845	train-pr_auc:0.731495	eval-pr_auc:0.688044
# [40]	train-auc:0.810363	eval-auc:0.791611	train-pr_auc:0.743623	eval-pr_auc:0.700512
# [60]	train-auc:0.816225	eval-auc:0.794681	train-pr_auc:0.750677	eval-pr_auc:0.704819
# [80]	train-auc:0.819876	eval-auc:0.796925	train-pr_auc:0.755515	eval-pr_auc:0.705326
# [100]	train-auc:0.823039	eval-auc:0.798539	train-pr_auc:0.760362	eval-pr_auc:0.70374
# [120]	train-auc:0.826131	eval-auc:0.799978	train-pr_auc:0.764968	eval-pr_auc:0.704105
# [140]	train-auc:0.828768	eval-auc:0.800774	train-pr_auc:0.768506	eval-pr_auc:0.704863
# [160]	train-auc:0.831348	eval-auc:0.801702	train-pr_auc:0.773198	eval-pr_auc:0.709897
# [180]	train-auc:0.833961	eval-auc:0.802524	train-pr_auc:0.77697	eval-pr_auc:0.710776
# [200]	train-auc:0.836061	eval-auc:0.803146	train-pr_auc:0.780151	eval-pr_auc:0.711897
# [220]	train-auc:0.83781	eval-auc:0.803975	train-pr_auc:0.783128	eval-pr_auc:0.71179
# [240]	train-auc:0.839444	eval-auc:0.805025	train-pr_auc:0.785704	eval-pr_auc:0.71163
# [260]	train-auc:0.841253	eval-auc:0.806046	train-pr_auc:0.7886	eval-pr_auc:0.713668
# [280]	train-auc:0.842896	eval-auc:0.806745	train-pr_auc:0.791216	eval-pr_auc:0.714917
# [300]	train-auc:0.844667	eval-auc:0.807528	train-pr_auc:0.794045	eval-pr_auc:0.716366
# [320]	train-auc:0.846455	eval-auc:0.80831	train-pr_auc:0.796795	eval-pr_auc:0.717126
# [340]	train-auc:0.848504	eval-auc:0.808998	train-pr_auc:0.799707	eval-pr_auc:0.718947
# [360]	train-auc:0.850264	eval-auc:0.809813	train-pr_auc:0.802151	eval-pr_auc:0.720206
# [380]	train-auc:0.852094	eval-auc:0.810625	train-pr_auc:0.804498	eval-pr_auc:0.722522
# [400]	train-auc:0.853621	eval-auc:0.811396	train-pr_auc:0.806584	eval-pr_auc:0.723819
# [420]	train-auc:0.854916	eval-auc:0.811847	train-pr_auc:0.80842	eval-pr_auc:0.724865
# [440]	train-auc:0.856557	eval-auc:0.812265	train-pr_auc:0.810577	eval-pr_auc:0.72599
# [460]	train-auc:0.858277	eval-auc:0.812478	train-pr_auc:0.812819	eval-pr_auc:0.72637
# [480]	train-auc:0.859877	eval-auc:0.812845	train-pr_auc:0.814805	eval-pr_auc:0.726796
# [500]	train-auc:0.86107	eval-auc:0.813285	train-pr_auc:0.816497	eval-pr_auc:0.727598
# Stopping. Best iteration:
# [0]	train-auc:0.781464	eval-auc:0.765987	train-pr_auc:0.71533	eval-pr_auc:0.662209
#
# ==========================================================

# %%
print(np.mean(auc_scores))
# Out:
# 0.8080068211790673

# %%
d_test_x = xgb.DMatrix(X_test)

pred_y_list = []
for model in models:
    pred_y = model.predict(d_test_x)
    pred_y_list.append(pred_y.reshape(-1,1))
    
xgb_pred_ensemble = np.mean(pred_y_list, axis = 0)
print(xgb_pred_ensemble)
# Out:
# [[0.84512615]
#  [0.22650436]
#  [0.3107174 ]
#  ...
#  [0.4771591 ]
#  [0.7451173 ]
#  [0.348636  ]]

# %%
sample_submssion = pd.read_csv('/content/drive/MyDrive/Colab/data/LG/sample_submission.csv')
sample_submssion['problem'] = xgb_pred_ensemble.reshape(-1)
sample_submssion.to_csv("/content/drive/MyDrive/Colab/data/LG/xgb_quality_0.808.csv", index = False)
sample_submssion
# Out:
#        user_id   problem
# 0        30000  0.945178
# 1        30001  0.228472
# 2        30002  0.256307
# 3        30003  0.488574
# 4        30004  0.688819
# ...        ...       ...
# 14994    44994  0.349955
# 14995    44995  0.233579
# 14996    44996  0.233375
# 14997    44997  0.842697
# 14998    44998  0.260301
#
# [14999 rows x 2 columns]
