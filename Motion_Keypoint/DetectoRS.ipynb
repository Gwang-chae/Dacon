# %%
# 이미 사전에 특정 위치에 설치한 관계로 경로 이동
# %cd drive/MyDrive

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version

# %%
# Colab 상에서의 mmdetection 환경설정

# install dependencies: (use cu101 because colab has CUDA 10.1)
# !pip install -U torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# # install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full

# # Install mmdetection
# !rm -rf mmdetection
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection

# !pip install -e .

# install Pillow 7.0.0 back in order to avoid bug in colab
# !pip install Pillow==7.0.0

# %%
# mmdetection의 config 파일들(model, dataset, schedule 등), mmdet/datasets/coco.py -> CocoDataset class 수정 필요
# 또한 usr/local/lib/python3.6/dist-packages/mmcv/runner/epoch_based_runner.py에서 latest.pth 파일이 안 생기게 끔 create_symlink=False로 수정해야 오류가 안 뜸.

# configs/detectors/detectors_0311 -> configs/detectors/detectors_cascade_x101 ~~~

# !python tools/train.py configs/detectors/detectors_0311.py
